# %% [markdown]
# # 5 number summary and box plot

# %%
import numpy as np

# %%
lst_marks = [23, 45, 67, 89, 12, 90, 34, 56, 78]
minimum, Q1, median, Q3, maximum=np.quantile(lst_marks, [0, 0.25, 0.5, 0.75, 1])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(12.0),
#  np.float64(34.0),
#  np.float64(56.0),
#  np.float64(78.0),
#  np.float64(90.0))

# %%
IQR = Q3 - Q1
print("Inter Quartile Range is:", IQR)
# Out:
# Inter Quartile Range is: 44.0

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print("Lower Bound is:", lower_bound)
print("Upper Bound is:", upper_bound)
# Out:
# Lower Bound is: -32.0
# Upper Bound is: 144.0

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks = [-100,-200, 23, 45, 67, 89, 12, 90, 34, 56, 78, 1000, 1200, 1300]
sns.boxplot(lst_marks)
# Out:
# <Axes: >
